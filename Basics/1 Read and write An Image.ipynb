# %%
import cv2
from matplotlib.pyplot import imshow
import numpy as np

# %%
image = cv2.imread("Data/Taylor.jpg",  cv2.IMREAD_COLOR)

# %%
imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB) )

# %%
cv2.imwrite("saved.jpg",  image)
# Out:
# True
